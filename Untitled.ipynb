ary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
#
#   company_location company_size
# 0               ES            L
# 1               US            S
# 2               US            S
# 3               CA            M

# %%
#show the laast 5 rows from the table 
ds_df.tail()
# Out:
#       work_year experience_level employment_type                 job_title  \
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
#        salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 3750   412000             USD         412000                 US           100
# 3751   151000             USD         151000                 US           100
# 3752   105000             USD         105000                 US           100
# 3753   100000             USD         100000                 US           100
# 3754  7000000             INR          94665                 IN            50
#
#      company_location company_size
# 3750               US            L
# 3751               US            L
# 3752               US            S
# 3753               US            L
# 3754               IN            L

# %%
#show the columns 
ds_df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
#show the columns data tyoe 
ds_df.dtypes
# Out:
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# remote_ratio           int64
# company_location      object
# company_size          object
# dtype: object

# %%
#total the columns and rows 
ds_df.shape
# Out:
# (3755, 11)

# %%
#show the max value 
ds_df['salary_in_usd'].max()
# Out:
# np.int64(450000)

# %%
#how vlaue is null 
ds_df.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
#show unique values and print it 
print('employment_type is',ds_df['employment_type'].unique())
print('experience_level is',ds_df['experience_level'].unique())
print('company_size is',ds_df['company_size'].unique())
# Out:
# employment_type is ['FT' 'CT' 'FL' 'PT']
# experience_level is ['SE' 'MI' 'EN' 'EX']
# company_size is ['L' 'S' 'M']

# %%
#creat new column his name salary in SR 
ds_df['salary in SR']=ds_df['salary_in_usd']*3.75
ds_df.head()
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
# 4  120000             USD         120000                 CA           100
#
#   company_location company_size  salary in SR
# 0               ES            L     321926.25
# 1               US            S     112500.00
# 2               US            S      95625.00
# 3               CA            M     656250.00
# 4               CA            M     450000.00

# %%
#show the salary in SR  column SR data type 
ds_df['salary in SR'].dtype
# Out:
# dtype('float64')

# %%
#changing salary in SR data type 
ds_df['salary in SR']=ds_df['salary in SR'].astype(int)
ds_df['salary in SR'].dtype
# Out:
# dtype('int64')

# %%
ds_df['salary in SR']=ds_df['salary in SR'].astype('int64')
ds_df['salary in SR'].dtype
# Out:
# dtype('int64')

# %%
#show the max value 
max=ds_df['salary in SR'].max()
min=ds_df['salary in SR'].min()
print('The max value ',max)
print('The min value ',min)
# Out:
# The max value  1687500
# The min value  19245

# %%
#creat new column his name salary in month
ds_df['salary in month ']=ds_df['salary in SR']/12
ds_df.head()
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
# 4  120000             USD         120000                 CA           100
#
#   company_location company_size  salary in SR  salary in month
# 0               ES            L        321926      26827.166667
# 1               US            S        112500       9375.000000
# 2               US            S         95625       7968.750000
# 3               CA            M        656250      54687.500000
# 4               CA            M        450000      37500.000000

# %%
ds_df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size', 'salary in SR',
#        'salary in month '],
#       dtype='object')

# %%
#replace value 
ds_df['company_size'].replace({'L': 'large','S': 'small','M':'Medium'} ,inplace=True)
ds_df['company_size']
# Out:
# 0        large
# 1        small
# 2        small
# 3       Medium
# 4       Medium
#          ...
# 3750     large
# 3751     large
# 3752     small
# 3753     large
# 3754     large
# Name: company_size, Length: 3755, dtype: object

# %%
ds_df.head()
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
# 4  120000             USD         120000                 CA           100
#
#   company_location company_size  salary in SR  salary in month
# 0               ES        large        321926      26827.166667
# 1               US        small        112500       9375.000000
# 2               US        small         95625       7968.750000
# 3               CA       Medium        656250      54687.500000
# 4               CA       Medium        450000      37500.000000

# %%
#remove columns from table 
ds_df.drop(columns=['salary','salary_currency','remote_ratio'] ,inplace=True)
ds_df.head()
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary_in_usd employee_residence company_location company_size  \
# 0          85847                 ES               ES        large
# 1          30000                 US               US        small
# 2          25500                 US               US        small
# 3         175000                 CA               CA       Medium
# 4         120000                 CA               CA       Medium
#
#    salary in SR  salary in month
# 0        321926      26827.166667
# 1        112500       9375.000000
# 2         95625       7968.750000
# 3        656250      54687.500000
# 4        450000      37500.000000

# %%
#install pyodbc provides access to ODBC (Open Database Connectivity) databases. 
# !pip install pyodbc
# Out:
# Collecting pyodbc
#   Downloading pyodbc-5.1.0-cp312-cp312-win_amd64.whl.metadata (2.8 kB)
# Downloading pyodbc-5.1.0-cp312-cp312-win_amd64.whl (69 kB)
#    ---------------------------------------- 0.0/69.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/69.3 kB ? eta -:--:--
#    ----- ---------------------------------- 10.2/69.3 kB ? eta -:--:--
#    ----- ---------------------------------- 10.2/69.3 kB ? eta -:--:--
#    ----------------- ---------------------- 30.7/69.3 kB 217.9 kB/s eta 0:00:01
#    ----------------------------------- ---- 61.4/69.3 kB 297.7 kB/s eta 0:00:01
#    ----------------------------------- ---- 61.4/69.3 kB 297.7 kB/s eta 0:00:01
#    ---------------------------------------- 69.3/69.3 kB 252.2 kB/s eta 0:00:00
# Installing collected packages: pyodbc
# Successfully installed pyodbc-5.1.0
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#install sqlalchemy and impotr it( provides a flexible and efficient way to work with databases.) 
#creat connect with SQL server(AAZ\SQLEXPRESS:server name ,lod=database name ) 

# !pip install sqlalchemy
import sqlalchemy as sql
engine= sql.create_engine(r'mssql://AAZ\SQLEXPRESS/lod?driver=ODBC+DRIVER+17+FOR+SQL+SERVER')
con=engine.connect()

# %%
#using the to_sql function in pandas to write a DataFrame (ds_df) to a SQL database table named 'work_year'
ds_df.to_sql('work_year',con=con,index=False,if_exists='replace')
# Out:
# -1

# %%
#creat new column his name new colimn
ds_df['new colimn']=ds_df['salary in SR']/20
ds_df.head()
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary_in_usd employee_residence company_location company_size  \
# 0          85847                 ES               ES        large
# 1          30000                 US               US        small
# 2          25500                 US               US        small
# 3         175000                 CA               CA       Medium
# 4         120000                 CA               CA       Medium
#
#    salary in SR  salary in month   new colimn
# 0        321926      26827.166667    16096.30
# 1        112500       9375.000000     5625.00
# 2         95625       7968.750000     4781.25
# 3        656250      54687.500000    32812.50
# 4        450000      37500.000000    22500.00

# %%
#rename the column from new colimn to new column
ds_df.rename(columns={'new colimn':'new column'},inplace=True)
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary_in_usd employee_residence company_location company_size  \
# 0          85847                 ES               ES        large
# 1          30000                 US               US        small
# 2          25500                 US               US        small
# 3         175000                 CA               CA       Medium
# 4         120000                 CA               CA       Medium
#
#    salary in SR  salary in month   new column
# 0        321926      26827.166667    16096.30
# 1        112500       9375.000000     5625.00
# 2         95625       7968.750000     4781.25
# 3        656250      54687.500000    32812.50
# 4        450000      37500.000000    22500.00
